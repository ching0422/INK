# %% [markdown]
# ## INK: explanatory notebook

# %% [markdown]
# Within this notebook, we give a simple example of how the INK library can be used to extract the neighbourhood of certain subjects of interest.<br>
# We also show the mining capabilities for both task specific and task agnostic cases.

# %% [markdown]
# The example dataset can be found in the /datasets folder.<br>
# We have used the common known animal dataset, describing several animals with their properties.

# %%
from ink.base.connectors import RDFLibConnector
from ink.base.structure import InkExtractor
from ink.miner.rulemining import RuleSetMiner

# %% [markdown]
# To start, three different packages are loaded.
# * A connector: which is used to load the original dataset.
# Here we have used an RDFLib connector, but other connectors are available.
# * The INK extractor, which will transform the neighbourhood of certain nodes into a binary representation.
# * The Rule Set Miner, which is our rule mining module.

# %%
import pandas as pd
import numpy as np

customer = pd.read_csv('train.tsv', sep='\t')
cus_seg = pd.read_csv('train.csv')

# %%
customer.head(2)
# Out:
#       subject     predicate          object
# 0  User462809        Gender      GenderMale
# 1  User462809  Ever_Married  Ever_MarriedNo

# %%
cus_seg.head(2)
# Out:
#        ID  Gender Ever_Married  Age Graduated  Profession  Work_Experience  \
# 0  462809    Male           No   22        No  Healthcare              1.0
# 1  462643  Female          Yes   38       Yes    Engineer              NaN
#
#   Spending_Score  Family_Size  Var_1 Segmentation
# 0            Low          4.0  Cat_4            D
# 1        Average          3.0  Cat_4            A

# %%
cus_seg["ID"] =  "User" + cus_seg.ID.astype(str).str.title().str.replace(" ", "")
for i in range(0,len(cus_seg)):
    if cus_seg["Segmentation"][i] == 'A':
        cus_seg["Segmentation"][i] =  1
    elif cus_seg["Segmentation"][i] == 'B':
        cus_seg["Segmentation"][i] =  2
    elif cus_seg["Segmentation"][i] == 'C':
        cus_seg["Segmentation"][i] =  3
    elif cus_seg["Segmentation"][i] == 'D':
        cus_seg["Segmentation"][i] =  4 
cus_seg.head(3)
# Out:
#            ID  Gender Ever_Married  Age Graduated  Profession  \
# 0  User462809    Male           No   22        No  Healthcare
# 1  User462643  Female          Yes   38       Yes    Engineer
# 2  User466315  Female          Yes   67       Yes    Engineer
#
#    Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0              1.0            Low          4.0  Cat_4            4
# 1              NaN        Average          3.0  Cat_4            1
# 2              1.0            Low          1.0  Cat_6            2

# %%
cus_sub = customer['subject'].unique() #row #6665

# %%
cus_pre = customer['predicate'].unique() #9
#cus_pre

# %%
cus_obj = customer['object'].unique() #116
#cus_obj

# %% [markdown]
# ##### four set of customer

# %%
A = set()
B = set()
C = set()
D = set()

# %%
#get segmentation
seg = []
for i in range(0,len(cus_sub)):
    idx = cus_seg[cus_seg['ID'] == cus_sub[i]]
    #print(idx.index)
    seg_idx = idx.index[0]
    seg.append(cus_seg['Segmentation'][seg_idx])
    if cus_seg['Segmentation'][seg_idx]==1:
        A.add(cus_sub[i])
    elif cus_seg['Segmentation'][seg_idx]==2:
        B.add(cus_sub[i])
    elif cus_seg['Segmentation'][seg_idx]==3:
        C.add(cus_sub[i])
    elif cus_seg['Segmentation'][seg_idx]==4:
        D.add(cus_sub[i])

# %%
y_train = np.array(seg)  #y_train #label
y_train
# Out:
# array([4, 2, 2, ..., 4, 2, 2])

# %% [markdown]
# ###### rule miner (不知道可不可以用(((o(*ﾟ▽ﾟ*)o))))

# %%
miner = RuleSetMiner(chains=100, max_len_rule_set=3, forest_size=10)

# %% [markdown]
# ###### task specific rule mining

# %%
df = pd.crosstab(customer['subject'], customer['object']) #add .ne(0) to transform 0,1 to True False

# %%
df.head(2)
# Out:
# object      Age18  Age19  Age20  Age21  Age22  Age23  Age25  Age26  Age27  \
# subject
# User458982      0      0      0      0      0      0      0      0      0
# User458983      0      0      0      0      0      0      0      0      0
#
# object      Age28  ...  Work_Experience13.0  Work_Experience14.0  \
# subject            ...
# User458982      0  ...                    0                    0
# User458983      0  ...                    0                    0
#
# object      Work_Experience2.0  Work_Experience3.0  Work_Experience4.0  \
# subject
# User458982                   0                   0                   0
# User458983                   0                   0                   0
#
# object      Work_Experience5.0  Work_Experience6.0  Work_Experience7.0  \
# subject
# User458982                   0                   0                   0
# User458983                   0                   0                   0
#
# object      Work_Experience8.0  Work_Experience9.0
# subject
# User458982                   0                   0
# User458983                   0                   0
#
# [2 rows x 116 columns]

# %%
df.filter(regex='^Age',axis=1).head(3)
# Out:
# object      Age18  Age19  Age20  Age21  Age22  Age23  Age25  Age26  Age27  \
# subject
# User458982      0      0      0      0      0      0      0      0      0
# User458983      0      0      0      0      0      0      0      0      0
# User458984      0      0      0      0      0      0      0      0      0
#
# object      Age28  ...  Age80  Age81  Age82  Age83  Age84  Age85  Age86  \
# subject            ...
# User458982      0  ...      0      0      0      0      0      0      0
# User458983      0  ...      0      0      0      0      0      0      0
# User458984      0  ...      0      0      0      0      0      0      0
#
# object      Age87  Age88  Age89
# subject
# User458982      0      0      0
# User458983      0      0      0
# User458984      0      0      0
#
# [3 rows x 67 columns]

# %%
df.columns = ['rdf#Gender§' + str(col) if col in df.filter(regex='^Gender',axis=1) else col for col in df.columns]
df.columns = ['rdf#Ever_Married§' + str(col) if col in df.filter(regex='^Ever_Married',axis=1) else col for col in df.columns]
df.columns = ['rdf#Age§' + str(col) if col in df.filter(regex='^Age',axis=1) else col for col in df.columns]
df.columns = ['rdf#everGraduated§' + str(col) if col in df.filter(regex='^everGraduated',axis=1) else col for col in df.columns]
df.columns = ['rdf#Profession§' + str(col) if col in df.filter(regex='^Profession',axis=1) else col for col in df.columns]
df.columns = ['rdf#Work_Experience§' + str(col) if col in df.filter(regex='^Work_Experience',axis=1) else col for col in df.columns]
df.columns = ['rdf#Spending_Score§' + str(col) if col in df.filter(regex='^Spending_Score',axis=1) else col for col in df.columns]
df.columns = ['rdf#Family_Size§' + str(col) if col in df.filter(regex='^Family_Size',axis=1) else col for col in df.columns]
df.columns = ['rdf#Var_1§' + str(col) if col in df.filter(regex='^Var_1',axis=1) else col for col in df.columns]

# %%
df.head(2)
# Out:
#             rdf#Age§Age18  rdf#Age§Age19  rdf#Age§Age20  rdf#Age§Age21  \
# subject
# User458982              0              0              0              0
# User458983              0              0              0              0
#
#             rdf#Age§Age22  rdf#Age§Age23  rdf#Age§Age25  rdf#Age§Age26  \
# subject
# User458982              0              0              0              0
# User458983              0              0              0              0
#
#             rdf#Age§Age27  rdf#Age§Age28  ...  \
# subject                                   ...
# User458982              0              0  ...
# User458983              0              0  ...
#
#             rdf#Work_Experience§Work_Experience13.0  \
# subject
# User458982                                        0
# User458983                                        0
#
#             rdf#Work_Experience§Work_Experience14.0  \
# subject
# User458982                                        0
# User458983                                        0
#
#             rdf#Work_Experience§Work_Experience2.0  \
# subject
# User458982                                       0
# User458983                                       0
#
#             rdf#Work_Experience§Work_Experience3.0  \
# subject
# User458982                                       0
# User458983                                       0
#
#             rdf#Work_Experience§Work_Experience4.0  \
# subject
# User458982                                       0
# User458983                                       0
#
#             rdf#Work_Experience§Work_Experience5.0  \
# subject
# User458982                                       0
# User458983                                       0
#
#             rdf#Work_Experience§Work_Experience6.0  \
# subject
# User458982                                       0
# User458983                                       0
#
#             rdf#Work_Experience§Work_Experience7.0  \
# subject
# User458982                                       0
# User458983                                       0
#
#             rdf#Work_Experience§Work_Experience8.0  \
# subject
# User458982                                       0
# User458983                                       0
#
#             rdf#Work_Experience§Work_Experience9.0
# subject
# User458982                                       0
# User458983                                       0
#
# [2 rows x 116 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6665 entries, User458982 to User467974
# Columns: 116 entries, rdf#Age§Age18 to rdf#Work_Experience§Work_Experience9.0
# dtypes: int64(116)
# memory usage: 5.9+ MB

# %%
from scipy.sparse import csr_matrix  #convert df to csr
df_csr = csr_matrix(df.values)
#df_csr

# %%
col = list(df.columns)
#col

# %%
X_train = (df_csr,list(cus_sub),col)
#X_train

# %%
#X_train: data
#y_train: label
acc, rules = miner.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [22], in <module>
# ----> 1 acc, rules = miner.fit(X_train, y_train)
#
# File ~\OneDrive\Desktop\hell\INK\ink\miner\rulemining.py:97, in RuleSetMiner.fit(self, data, label)
#      89 """
#      90 Fit function to train the classifier or generate agnostic rules
#      91 :param data: Tuple value containing 1) a sparse binary representation, 2) list of indices, 3) column features.
#    (...)
#      94 :return: Rules
#      95 """
#      96 if label is not None:
# ---> 97     return specific_fit(self, data, label)
#      98 else:
#      99     return agnostic_fit(self, data)
#
# File ~\OneDrive\Desktop\hell\INK\ink\miner\task_specific_mining.py:39, in specific_fit(miner, X_trans, y)
#      37 df.columns = X_trans[2]
#      38 X_trans = df.astype('bool')
# ---> 39 miner.precompute(y)
#      40 __specific_rules(miner, X_trans, y)
#      41 miner.attributeNames = X_trans.columns
#
# File ~\OneDrive\Desktop\hell\INK\ink\miner\rulemining.py:184, in RuleSetMiner.precompute(self, y)
#     180 TP, FP, TN, FN = sum(y), 0, len(y) - sum(y), 0
#     181 # self.Lup : p(S|A;alpha_+,beta_+,alpha_-,beta_-)
#     182 # conference paper formula(6)
#     183 self.Lup = (utils.log_betabin(TP, TP + FP, self.alpha_1, self.beta_1)
# --> 184             + utils.log_betabin(TN, FN + TN, self.alpha_2, self.beta_2))
#     185 # self.const_denominator : log((|Al|+beta_l-1)/(alpha_l+|Al|-1))
#     186 # conference paper formula(9) denominator
#     187 self.const_denominator = [np.log((self.patternSpace[i] + self.beta_l[i] - 1)
#     188                                  / (self.patternSpace[i] + self.alpha_l[i] - 1))
#     189                           for i in range(self.max_rule_set + 1)]
#
# File ~\OneDrive\Desktop\hell\INK\ink\miner\utils.py:38, in log_betabin(k, n, alpha, beta)
#      36     return np.array(lbeta)
#      37 else:
# ---> 38     return math.lgamma(k + alpha) + math.lgamma(n - k + beta) - math.lgamma(n + alpha + beta) + c
#
# ValueError: math domain error

# %%
col = []
#for i in range (0,len(customer)):  #fill with True/False
#    col.append('count.rdf#')

# %%
#fill with 0,1
for i in range (0,len(customer)):
    if "Gender" in customer['object'][i]: 
        text = 'rdf#Gender§' + customer['object'][i]
    if "Ever_Married" in customer['object'][i]:
        text = 'rdf#Ever_Married§' + customer['object'][i]
    if "Age" in customer['object'][i]:
        text = 'rdf#Age§' + customer['object'][i]
    if "everGraduated" in customer['object'][i]:
        text = 'rdf#everGraduated§' + customer['object'][i]
    if "Profession" in customer['object'][i]:
        text = 'rdf#Profession§' + customer['object'][i]
    if "Work_Experience" in customer['object'][i]:
        text = 'rdf#Work_Experience§' + customer['object'][i]
    if "Spending_Score" in customer['object'][i]:
        text = 'rdf#Spending_Score§' + customer['object'][i]
    if "Family_Size" in customer['object'][i]:
        text = 'rdf#Family_Size§' + customer['object'][i]
    if "Var_1" in customer['object'][i]:
        text = 'rdf#Var_1§' + customer['object'][i]
    
    if text not in col:
        col.append(text) #store all possible col

# %%
col
# Out:
# ['rdf#Gender§GenderMale',
#  'rdf#Ever_Married§Ever_MarriedNo',
#  'rdf#Age§Age22',
#  'rdf#Profession§ProfessionHealthcare',
#  'rdf#Work_Experience§Work_Experience1.0',
#  'rdf#Spending_Score§Spending_ScoreLow',
#  'rdf#Family_Size§Family_Size4.0',
#  'rdf#Var_1§Var_1Cat_4',
#  'rdf#Gender§GenderFemale',
#  'rdf#Ever_Married§Ever_MarriedYes',
#  'rdf#Age§Age67',
#  'rdf#Profession§ProfessionEngineer',
#  'rdf#Family_Size§Family_Size1.0',
#  'rdf#Var_1§Var_1Cat_6',
#  'rdf#Profession§ProfessionLawyer',
#  'rdf#Work_Experience§Work_Experience0.0',
#  'rdf#Spending_Score§Spending_ScoreHigh',
#  'rdf#Family_Size§Family_Size2.0',
#  'rdf#Age§Age56',
#  'rdf#Profession§ProfessionArtist',
#  'rdf#Spending_Score§Spending_ScoreAverage',
#  'rdf#Age§Age32',
#  'rdf#Family_Size§Family_Size3.0',
#  'rdf#Age§Age33',
#  'rdf#Age§Age61',
#  'rdf#Var_1§Var_1Cat_7',
#  'rdf#Age§Age55',
#  'rdf#Age§Age26',
#  'rdf#Age§Age19',
#  'rdf#Work_Experience§Work_Experience4.0',
#  'rdf#Age§Age58',
#  'rdf#Profession§ProfessionDoctor',
#  'rdf#Var_1§Var_1Cat_3',
#  'rdf#Age§Age41',
#  'rdf#Var_1§Var_1Cat_1',
#  'rdf#Profession§ProfessionHomemaker',
#  'rdf#Work_Experience§Work_Experience9.0',
#  'rdf#Family_Size§Family_Size5.0',
#  'rdf#Age§Age31',
#  'rdf#Family_Size§Family_Size6.0',
#  'rdf#Profession§ProfessionEntertainment',
#  'rdf#Age§Age79',
#  'rdf#Age§Age49',
#  'rdf#Work_Experience§Work_Experience12.0',
#  'rdf#Age§Age18',
#  'rdf#Work_Experience§Work_Experience3.0',
#  'rdf#Work_Experience§Work_Experience13.0',
#  'rdf#Age§Age36',
#  'rdf#Work_Experience§Work_Experience5.0',
#  'rdf#Family_Size§Family_Size8.0',
#  'rdf#Age§Age35',
#  'rdf#Age§Age45',
#  'rdf#Age§Age42',
#  'rdf#Var_1§Var_1Cat_2',
#  'rdf#Age§Age83',
#  'rdf#Age§Age27',
#  'rdf#Age§Age28',
#  'rdf#Work_Experience§Work_Experience8.0',
#  'rdf#Age§Age47',
#  'rdf#Work_Experience§Work_Experience14.0',
#  'rdf#Age§Age40',
#  'rdf#Age§Age57',
#  'rdf#Age§Age76',
#  'rdf#Profession§ProfessionMarketing',
#  'rdf#Age§Age25',
#  'rdf#Age§Age48',
#  'rdf#Age§Age74',
#  'rdf#Age§Age59',
#  'rdf#Work_Experience§Work_Experience7.0',
#  'rdf#Age§Age51',
#  'rdf#Work_Experience§Work_Experience2.0',
#  'rdf#Age§Age30',
#  'rdf#Work_Experience§Work_Experience6.0',
#  'rdf#Var_1§Var_1Cat_5',
#  'rdf#Age§Age63',
#  'rdf#Age§Age52',
#  'rdf#Age§Age39',
#  'rdf#Age§Age38',
#  'rdf#Age§Age60',
#  'rdf#Age§Age68',
#  'rdf#Profession§ProfessionExecutive',
#  'rdf#Family_Size§Family_Size7.0',
#  'rdf#Work_Experience§Work_Experience10.0',
#  'rdf#Age§Age86',
#  'rdf#Age§Age43',
#  'rdf#Age§Age80',
#  'rdf#Age§Age37',
#  'rdf#Age§Age46',
#  'rdf#Age§Age72',
#  'rdf#Age§Age69',
#  'rdf#Age§Age50',
#  'rdf#Age§Age29',
#  'rdf#Age§Age71',
#  'rdf#Family_Size§Family_Size9.0',
#  'rdf#Age§Age78',
#  'rdf#Age§Age82',
#  'rdf#Age§Age70',
#  'rdf#Age§Age23',
#  'rdf#Work_Experience§Work_Experience11.0',
#  'rdf#Age§Age20',
#  'rdf#Age§Age21',
#  'rdf#Age§Age53',
#  'rdf#Age§Age75',
#  'rdf#Age§Age65',
#  'rdf#Age§Age89',
#  'rdf#Age§Age62',
#  'rdf#Age§Age66',
#  'rdf#Age§Age73',
#  'rdf#Age§Age77',
#  'rdf#Age§Age87',
#  'rdf#Age§Age84',
#  'rdf#Age§Age88',
#  'rdf#Age§Age85',
#  'rdf#Age§Age81']
